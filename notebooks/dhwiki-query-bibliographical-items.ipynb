# %% [markdown]
# <img src="../images/DHWiki_banner.png" width="30%">
#
# This is an example of reuse of the [DHwiki Wikibase](https://dhwiki.wikibase.cloud/wiki/Main_Page), hosted on [Wikibase Cloud](https://wikibase.cloud/), includes a Wikibase instance, and is maintained since September 2024 by the [DARIAH-EU WG DHwiki](https://www.dariah.eu/activities/working-groups/dhwiki/), in the framework of the [DARIAH ERIC](https://www.dariah.eu/).

# %% [markdown]
# First of all, we include all the python packages that are required to run this example. We will use the SPARQL endpoint to query the data and retrieve the classes and instances on this Wikibase.

# %%
from SPARQLWrapper import SPARQLWrapper, JSON, RDFXML, POST

sparql = SPARQLWrapper(
    "https://dhwiki.wikibase.cloud/query/sparql"
)
sparql.setReturnFormat(RDFXML)
sparql.setMethod(POST)
sparql.setReturnFormat(JSON)

# %% [markdown]
# Now, we define the SPARQL query. This example is available in the [DHwiki Wikibase as an example](https://dhwiki.wikibase.cloud/wiki/Main_Page).

# %%
sparql.setQuery("""
PREFIX dhwb: <https://dhwiki.wikibase.cloud/entity/>
PREFIX dhdp: <https://dhwiki.wikibase.cloud/prop/direct/>

select ?item ?typeLabel ?date ?itemLabel ?langLabel (iri(concat(str(wd:),?wd)) as ?wikidata)
       
where { 
  # ?item dhdp:P5 dhwb:Q2; dhdp:P8 ?type; dhdp:P26 ?date; dhdp:P11 ?lang.
  optional {?item dhdp:P1 ?wd.}
  
  SERVICE wikibase:label { bd:serviceParam wikibase:language "[AUTO_LANGUAGE],en". }
} order by desc(year(?date))
"""
)

# %% [markdown]
# Finally, we can retrieve the triples as JSON using the following code:

# %%
try:
    ret = sparql.queryAndConvert()
    #print(ret)
    for r in ret["results"]["bindings"]:
        print(r["item"]["value"] + " - " + r["typeLabel"]["value"])
except Exception as e:
    print(e)
# Out:
# https://dhwiki.wikibase.cloud/entity/Q533 - journal article
# https://dhwiki.wikibase.cloud/entity/Q535 - presentation
# https://dhwiki.wikibase.cloud/entity/Q536 - presentation
# https://dhwiki.wikibase.cloud/entity/Q539 - presentation
# https://dhwiki.wikibase.cloud/entity/Q562 - presentation
# https://dhwiki.wikibase.cloud/entity/Q563 - book section
# https://dhwiki.wikibase.cloud/entity/Q564 - presentation
# https://dhwiki.wikibase.cloud/entity/Q567 - journal article
# https://dhwiki.wikibase.cloud/entity/Q572 - journal article
# https://dhwiki.wikibase.cloud/entity/Q573 - journal article
# https://dhwiki.wikibase.cloud/entity/Q581 - blog post
# https://dhwiki.wikibase.cloud/entity/Q582 - blog post
# https://dhwiki.wikibase.cloud/entity/Q583 - blog post
# https://dhwiki.wikibase.cloud/entity/Q526 - journal article
# https://dhwiki.wikibase.cloud/entity/Q528 - journal article
# https://dhwiki.wikibase.cloud/entity/Q534 - journal article
# https://dhwiki.wikibase.cloud/entity/Q537 - journal article
# https://dhwiki.wikibase.cloud/entity/Q538 - thesis
# https://dhwiki.wikibase.cloud/entity/Q547 - presentation
# https://dhwiki.wikibase.cloud/entity/Q549 - journal article
# https://dhwiki.wikibase.cloud/entity/Q552 - journal article
# https://dhwiki.wikibase.cloud/entity/Q558 - journal article
# https://dhwiki.wikibase.cloud/entity/Q566 - journal article
# https://dhwiki.wikibase.cloud/entity/Q479 - presentation
# https://dhwiki.wikibase.cloud/entity/Q482 - book section
# https://dhwiki.wikibase.cloud/entity/Q483 - presentation
# https://dhwiki.wikibase.cloud/entity/Q221 - presentation
# https://dhwiki.wikibase.cloud/entity/Q227 - presentation
# https://dhwiki.wikibase.cloud/entity/Q212 - presentation
# https://dhwiki.wikibase.cloud/entity/Q229 - blog post
# https://dhwiki.wikibase.cloud/entity/Q230 - book section
# https://dhwiki.wikibase.cloud/entity/Q250 - book
# https://dhwiki.wikibase.cloud/entity/Q250 - report
# https://dhwiki.wikibase.cloud/entity/Q259 - book
# https://dhwiki.wikibase.cloud/entity/Q444 - blog post
# https://dhwiki.wikibase.cloud/entity/Q446 - book section
# https://dhwiki.wikibase.cloud/entity/Q447 - book section
# https://dhwiki.wikibase.cloud/entity/Q466 - presentation
# https://dhwiki.wikibase.cloud/entity/Q467 - book section
# https://dhwiki.wikibase.cloud/entity/Q468 - journal article
# https://dhwiki.wikibase.cloud/entity/Q470 - presentation
# https://dhwiki.wikibase.cloud/entity/Q471 - presentation
# https://dhwiki.wikibase.cloud/entity/Q472 - presentation
# https://dhwiki.wikibase.cloud/entity/Q473 - presentation
# https://dhwiki.wikibase.cloud/entity/Q474 - conference paper
# https://dhwiki.wikibase.cloud/entity/Q484 - journal article
# https://dhwiki.wikibase.cloud/entity/Q530 - conference paper
# https://dhwiki.wikibase.cloud/entity/Q532 - preprint
# https://dhwiki.wikibase.cloud/entity/Q541 - book section
# https://dhwiki.wikibase.cloud/entity/Q543 - journal article
# https://dhwiki.wikibase.cloud/entity/Q559 - journal article
# https://dhwiki.wikibase.cloud/entity/Q560 - journal article
# https://dhwiki.wikibase.cloud/entity/Q565 - journal article
# https://dhwiki.wikibase.cloud/entity/Q571 - book section
# https://dhwiki.wikibase.cloud/entity/Q576 - conference paper
# https://dhwiki.wikibase.cloud/entity/Q578 - conference paper
# https://dhwiki.wikibase.cloud/entity/Q481 - conference paper
# https://dhwiki.wikibase.cloud/entity/Q222 - journal article
# https://dhwiki.wikibase.cloud/entity/Q226 - journal article
# https://dhwiki.wikibase.cloud/entity/Q268 - journal article
# https://dhwiki.wikibase.cloud/entity/Q270 - journal article
# https://dhwiki.wikibase.cloud/entity/Q278 - journal article
# https://dhwiki.wikibase.cloud/entity/Q281 - journal article
# https://dhwiki.wikibase.cloud/entity/Q207 - web page
# https://dhwiki.wikibase.cloud/entity/Q220 - conference paper
# https://dhwiki.wikibase.cloud/entity/Q224 - journal article
# https://dhwiki.wikibase.cloud/entity/Q215 - conference paper
# https://dhwiki.wikibase.cloud/entity/Q232 - presentation
# https://dhwiki.wikibase.cloud/entity/Q234 - presentation
# https://dhwiki.wikibase.cloud/entity/Q242 - presentation
# https://dhwiki.wikibase.cloud/entity/Q247 - book section
# https://dhwiki.wikibase.cloud/entity/Q252 - presentation
# https://dhwiki.wikibase.cloud/entity/Q262 - journal article
# https://dhwiki.wikibase.cloud/entity/Q266 - book section
# https://dhwiki.wikibase.cloud/entity/Q269 - report
# https://dhwiki.wikibase.cloud/entity/Q285 - report
# https://dhwiki.wikibase.cloud/entity/Q475 - book section
# https://dhwiki.wikibase.cloud/entity/Q531 - conference paper
# https://dhwiki.wikibase.cloud/entity/Q540 - journal article
# https://dhwiki.wikibase.cloud/entity/Q545 - journal article
# https://dhwiki.wikibase.cloud/entity/Q550 - journal article
# https://dhwiki.wikibase.cloud/entity/Q556 - journal article
# https://dhwiki.wikibase.cloud/entity/Q557 - conference paper
# https://dhwiki.wikibase.cloud/entity/Q561 - journal article
# https://dhwiki.wikibase.cloud/entity/Q577 - conference paper
# https://dhwiki.wikibase.cloud/entity/Q580 - blog post
# https://dhwiki.wikibase.cloud/entity/Q211 - journal article
# https://dhwiki.wikibase.cloud/entity/Q277 - conference paper
# https://dhwiki.wikibase.cloud/entity/Q280 - journal article
# https://dhwiki.wikibase.cloud/entity/Q284 - journal article
# https://dhwiki.wikibase.cloud/entity/Q218 - journal article
# https://dhwiki.wikibase.cloud/entity/Q219 - book section
# https://dhwiki.wikibase.cloud/entity/Q225 - presentation
# https://dhwiki.wikibase.cloud/entity/Q209 - conference paper
# https://dhwiki.wikibase.cloud/entity/Q210 - book
# https://dhwiki.wikibase.cloud/entity/Q231 - presentation
# https://dhwiki.wikibase.cloud/entity/Q238 - presentation
# https://dhwiki.wikibase.cloud/entity/Q249 - conference paper
# https://dhwiki.wikibase.cloud/entity/Q249 - journal article
# https://dhwiki.wikibase.cloud/entity/Q273 - report
# https://dhwiki.wikibase.cloud/entity/Q263 - book
# https://dhwiki.wikibase.cloud/entity/Q265 - book
# https://dhwiki.wikibase.cloud/entity/Q265 - report
# https://dhwiki.wikibase.cloud/entity/Q267 - report
# https://dhwiki.wikibase.cloud/entity/Q478 - journal article
# https://dhwiki.wikibase.cloud/entity/Q485 - blog post
# https://dhwiki.wikibase.cloud/entity/Q524 - conference paper
# https://dhwiki.wikibase.cloud/entity/Q525 - preprint
# https://dhwiki.wikibase.cloud/entity/Q544 - conference paper
# https://dhwiki.wikibase.cloud/entity/Q551 - journal article
# https://dhwiki.wikibase.cloud/entity/Q575 - report
# https://dhwiki.wikibase.cloud/entity/Q579 - journal article
# https://dhwiki.wikibase.cloud/entity/Q480 - journal article
# https://dhwiki.wikibase.cloud/entity/Q235 - journal article
# https://dhwiki.wikibase.cloud/entity/Q256 - journal article
# https://dhwiki.wikibase.cloud/entity/Q214 - video recording
# https://dhwiki.wikibase.cloud/entity/Q233 - presentation
# https://dhwiki.wikibase.cloud/entity/Q261 - book
# https://dhwiki.wikibase.cloud/entity/Q261 - report
# https://dhwiki.wikibase.cloud/entity/Q286 - report
# https://dhwiki.wikibase.cloud/entity/Q276 - conference paper
# https://dhwiki.wikibase.cloud/entity/Q276 - presentation
# https://dhwiki.wikibase.cloud/entity/Q469 - journal article
# https://dhwiki.wikibase.cloud/entity/Q574 - conference paper
# https://dhwiki.wikibase.cloud/entity/Q240 - journal article
# https://dhwiki.wikibase.cloud/entity/Q217 - conference paper
# https://dhwiki.wikibase.cloud/entity/Q239 - conference paper
# https://dhwiki.wikibase.cloud/entity/Q279 - journal article
# https://dhwiki.wikibase.cloud/entity/Q477 - journal article
# https://dhwiki.wikibase.cloud/entity/Q529 - conference paper
# https://dhwiki.wikibase.cloud/entity/Q546 - book section
# https://dhwiki.wikibase.cloud/entity/Q553 - report
# https://dhwiki.wikibase.cloud/entity/Q569 - conference paper
# https://dhwiki.wikibase.cloud/entity/Q570 - thesis
# https://dhwiki.wikibase.cloud/entity/Q236 - conference paper
# https://dhwiki.wikibase.cloud/entity/Q241 - journal article
# https://dhwiki.wikibase.cloud/entity/Q244 - journal article
# https://dhwiki.wikibase.cloud/entity/Q255 - journal article
# https://dhwiki.wikibase.cloud/entity/Q208 - report
# https://dhwiki.wikibase.cloud/entity/Q245 - journal article
# https://dhwiki.wikibase.cloud/entity/Q246 - journal article
# https://dhwiki.wikibase.cloud/entity/Q257 - journal article
# https://dhwiki.wikibase.cloud/entity/Q216 - journal article
# https://dhwiki.wikibase.cloud/entity/Q253 - journal article
# https://dhwiki.wikibase.cloud/entity/Q213 - conference paper
# https://dhwiki.wikibase.cloud/entity/Q237 - book section
# https://dhwiki.wikibase.cloud/entity/Q282 - journal article
# https://dhwiki.wikibase.cloud/entity/Q527 - conference paper
# https://dhwiki.wikibase.cloud/entity/Q228 - conference paper
# https://dhwiki.wikibase.cloud/entity/Q251 - book section
# https://dhwiki.wikibase.cloud/entity/Q272 - book
# https://dhwiki.wikibase.cloud/entity/Q275 - book
# https://dhwiki.wikibase.cloud/entity/Q542 - book section
# https://dhwiki.wikibase.cloud/entity/Q264 - book section
# https://dhwiki.wikibase.cloud/entity/Q568 - book section
# https://dhwiki.wikibase.cloud/entity/Q274 - book
# https://dhwiki.wikibase.cloud/entity/Q258 - journal article
# https://dhwiki.wikibase.cloud/entity/Q243 - book section
# https://dhwiki.wikibase.cloud/entity/Q223 - conference paper
# https://dhwiki.wikibase.cloud/entity/Q248 - conference paper
# https://dhwiki.wikibase.cloud/entity/Q283 - book section
# https://dhwiki.wikibase.cloud/entity/Q254 - journal article
# https://dhwiki.wikibase.cloud/entity/Q271 - conference paper
# https://dhwiki.wikibase.cloud/entity/Q260 - book
