# %% [markdown]
# <img src="../images/DHWiki_banner.png" width="30%">
#
# This is an example of reuse of the [DHwiki Wikibase](https://dhwiki.wikibase.cloud/wiki/Main_Page), hosted on [Wikibase Cloud](https://wikibase.cloud/), includes a Wikibase instance, and is maintained since September 2024 by the [DARIAH-EU WG DHwiki](https://www.dariah.eu/activities/working-groups/dhwiki/), in the framework of the [DARIAH ERIC](https://www.dariah.eu/).

# %% [markdown]
# First of all, we include all the python packages that are required to run this example. We will use the SPARQL endpoint to query the data and retrieve the classes and instances on this Wikibase.

# %%
from SPARQLWrapper import SPARQLWrapper, JSON, RDFXML, POST

sparql = SPARQLWrapper(
    "https://dhwiki.wikibase.cloud/query/sparql"
)
sparql.setReturnFormat(RDFXML)
sparql.setMethod(POST)
sparql.setReturnFormat(JSON)

# %% [markdown]
# Now, we define the SPARQL query. This example is available in the [DHwiki Wikibase as an example](https://dhwiki.wikibase.cloud/wiki/Main_Page).

# %%
sparql.setQuery("""
PREFIX dhwb: <https://dhwiki.wikibase.cloud/entity/>
PREFIX dhdp: <https://dhwiki.wikibase.cloud/prop/direct/>

select ?item ?typeLabel ?date ?itemLabel ?langLabel (iri(concat(str(wd:),?wd)) as ?wikidata)
       
where { 
  # ?item dhdp:P5 dhwb:Q2; dhdp:P8 ?type; dhdp:P26 ?date; dhdp:P11 ?lang.
  optional {?item dhdp:P1 ?wd.}
  
  SERVICE wikibase:label { bd:serviceParam wikibase:language "[AUTO_LANGUAGE],en". }
} order by desc(year(?date))
"""
)

# %% [markdown]
# Finally, we can retrieve the triples as JSON using the following code:

# %%
try:
    ret = sparql.queryAndConvert()
    print(ret)
    for r in ret["results"]["bindings"]:
        print(r)
except Exception as e:
    print(e)
# Out:
# {'head': {'vars': ['item', 'typeLabel', 'date', 'itemLabel', 'langLabel', 'wikidata']}, 'results': {'bindings': [{'item': {'type': 'uri', 'value': 'https://dhwiki.wikibase.cloud/entity/Q533'}, 'date': {'datatype': 'http://www.w3.org/2001/XMLSchema#dateTime', 'type': 'literal', 'value': '2025-01-14T00:00:00Z'}, 'typeLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'journal article'}, 'itemLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'ClaG: A classification system for plays and games in toy libraries and libraries'}, 'langLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'English'}}, {'item': {'type': 'uri', 'value': 'https://dhwiki.wikibase.cloud/entity/Q535'}, 'date': {'datatype': 'http://www.w3.org/2001/XMLSchema#dateTime', 'type': 'literal', 'value': '2025-01-16T00:00:00Z'}, 'typeLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'presentation'}, 'itemLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Datos lexicográficos en Wikibase y Wikidata: Perspectivas para el Mirandés'}, 'langLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Spanish'}}, {'item': {'type': 'uri', 'value': 'https://dhwiki.wikibase.cloud/entity/Q536'}, 'date': {'datatype': 'http://www.w3.org/2001/XMLSchema#dateTime', 'type': 'literal', 'value': '2025-01-14T00:00:00Z'}, 'typeLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'presentation'}, 'itemLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'FAIR Data on Wiki-Platforms'}, 'langLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'English'}}, {'item': {'type': 'uri', 'value': 'https://dhwiki.wikibase.cloud/entity/Q539'}, 'date': {'datatype': 'http://www.w3.org/2001/XMLSchema#dateTime', 'type': 'literal', 'value': '2025-01-10T00:00:00Z'}, 'typeLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'presentation'}, 'itemLabel': {'xml:lang': 'en', 'type': 'literal', 'value': "Wikibase e Wikidata per lo studio dell'epigrafia greca"}, 'langLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Italian'}}, {'item': {'type': 'uri', 'value': 'https://dhwiki.wikibase.cloud/entity/Q562'}, 'date': {'datatype': 'http://www.w3.org/2001/XMLSchema#dateTime', 'type': 'literal', 'value': '2025-03-18T00:00:00Z'}, 'typeLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'presentation'}, 'itemLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Zotero and Wikibase: Workflows for a term-indexed article collection'}, 'langLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'English'}}, {'item': {'type': 'uri', 'value': 'https://dhwiki.wikibase.cloud/entity/Q563'}, 'date': {'datatype': 'http://www.w3.org/2001/XMLSchema#dateTime', 'type': 'literal', 'value': '2025-01-01T00:00:00Z'}, 'typeLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'book section'}, 'itemLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Ziterauzi: euskarazko artikulu akademikoetatik zitazioak erauzteko tresna-katea'}, 'langLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Basque'}}, {'item': {'type': 'uri', 'value': 'https://dhwiki.wikibase.cloud/entity/Q564'}, 'date': {'datatype': 'http://www.w3.org/2001/XMLSchema#dateTime', 'type': 'literal', 'value': '2025-01-11T00:00:00Z'}, 'typeLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'presentation'}, 'itemLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'The Wikibase Software: Data and Collections in the Linked Open Data Web'}, 'langLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'English'}}, {'item': {'type': 'uri', 'value': 'https://dhwiki.wikibase.cloud/entity/Q567'}, 'date': {'datatype': 'http://www.w3.org/2001/XMLSchema#dateTime', 'type': 'literal', 'value': '2025-01-27T00:00:00Z'}, 'typeLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'journal article'}, 'itemLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Knowledge Graphing Art Archives: Methods and Tools from the Semantic Lab’s E.A.T. Project'}, 'langLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'English'}}, {'item': {'type': 'uri', 'va ...
# {'item': {'type': 'uri', 'value': 'https://dhwiki.wikibase.cloud/entity/Q533'}, 'date': {'datatype': 'http://www.w3.org/2001/XMLSchema#dateTime', 'type': 'literal', 'value': '2025-01-14T00:00:00Z'}, 'typeLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'journal article'}, 'itemLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'ClaG: A classification system for plays and games in toy libraries and libraries'}, 'langLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'English'}}
# {'item': {'type': 'uri', 'value': 'https://dhwiki.wikibase.cloud/entity/Q535'}, 'date': {'datatype': 'http://www.w3.org/2001/XMLSchema#dateTime', 'type': 'literal', 'value': '2025-01-16T00:00:00Z'}, 'typeLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'presentation'}, 'itemLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Datos lexicográficos en Wikibase y Wikidata: Perspectivas para el Mirandés'}, 'langLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Spanish'}}
# {'item': {'type': 'uri', 'value': 'https://dhwiki.wikibase.cloud/entity/Q536'}, 'date': {'datatype': 'http://www.w3.org/2001/XMLSchema#dateTime', 'type': 'literal', 'value': '2025-01-14T00:00:00Z'}, 'typeLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'presentation'}, 'itemLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'FAIR Data on Wiki-Platforms'}, 'langLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'English'}}
# {'item': {'type': 'uri', 'value': 'https://dhwiki.wikibase.cloud/entity/Q539'}, 'date': {'datatype': 'http://www.w3.org/2001/XMLSchema#dateTime', 'type': 'literal', 'value': '2025-01-10T00:00:00Z'}, 'typeLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'presentation'}, 'itemLabel': {'xml:lang': 'en', 'type': 'literal', 'value': "Wikibase e Wikidata per lo studio dell'epigrafia greca"}, 'langLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Italian'}}
# {'item': {'type': 'uri', 'value': 'https://dhwiki.wikibase.cloud/entity/Q562'}, 'date': {'datatype': 'http://www.w3.org/2001/XMLSchema#dateTime', 'type': 'literal', 'value': '2025-03-18T00:00:00Z'}, 'typeLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'presentation'}, 'itemLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Zotero and Wikibase: Workflows for a term-indexed article collection'}, 'langLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'English'}}
# {'item': {'type': 'uri', 'value': 'https://dhwiki.wikibase.cloud/entity/Q563'}, 'date': {'datatype': 'http://www.w3.org/2001/XMLSchema#dateTime', 'type': 'literal', 'value': '2025-01-01T00:00:00Z'}, 'typeLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'book section'}, 'itemLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Ziterauzi: euskarazko artikulu akademikoetatik zitazioak erauzteko tresna-katea'}, 'langLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Basque'}}
# {'item': {'type': 'uri', 'value': 'https://dhwiki.wikibase.cloud/entity/Q564'}, 'date': {'datatype': 'http://www.w3.org/2001/XMLSchema#dateTime', 'type': 'literal', 'value': '2025-01-11T00:00:00Z'}, 'typeLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'presentation'}, 'itemLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'The Wikibase Software: Data and Collections in the Linked Open Data Web'}, 'langLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'English'}}
# {'item': {'type': 'uri', 'value': 'https://dhwiki.wikibase.cloud/entity/Q567'}, 'date': {'datatype': 'http://www.w3.org/2001/XMLSchema#dateTime', 'type': 'literal', 'value': '2025-01-27T00:00:00Z'}, 'typeLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'journal article'}, 'itemLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Knowledge Graphing Art Archives: Methods and Tools from the Semantic Lab’s E.A.T. Project'}, 'langLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'English'}}
# {'item': {'type': 'uri', 'value': 'https://dhwiki.wikibase.cloud/entity/Q572'}, 'date': {'datatype': 'http://www.w3.org/2001/XMLSchema#dateTime', 'type': 'literal', 'value': '2025-01-01T00:00:00Z'}, 'typeLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'journal article'}, 'itemLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Termini, dati e collegamenti: ‘conversazioni’ tra il Thesaurus del Nuovo soggettario e Wikidata'}, 'langLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Italian'}}
# {'item': {'type': 'uri', 'value': 'https://dhwiki.wikibase.cloud/entity/Q573'}, 'date': {'datatype': 'http://www.w3.org/2001/XMLSchema#dateTime', 'type': 'literal', 'value': '2025-05-19T00:00:00Z'}, 'typeLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'journal article'}, 'itemLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Exploring the adoption of collections as data in the GLAM context'}, 'langLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'English'}}
# {'item': {'type': 'uri', 'value': 'https://dhwiki.wikibase.cloud/entity/Q581'}, 'date': {'datatype': 'http://www.w3.org/2001/XMLSchema#dateTime', 'type': 'literal', 'value': '2025-05-03T00:00:00Z'}, 'typeLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'blog post'}, 'itemLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Communicating Ontology'}, 'langLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'English'}}
# {'item': {'type': 'uri', 'value': 'https://dhwiki.wikibase.cloud/entity/Q582'}, 'date': {'datatype': 'http://www.w3.org/2001/XMLSchema#dateTime', 'type': 'literal', 'value': '2025-02-28T00:00:00Z'}, 'typeLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'blog post'}, 'itemLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Unlocking knowledge at Utrecht University'}, 'langLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'English'}}
# {'item': {'type': 'uri', 'value': 'https://dhwiki.wikibase.cloud/entity/Q583'}, 'date': {'datatype': 'http://www.w3.org/2001/XMLSchema#dateTime', 'type': 'literal', 'value': '2025-02-10T00:00:00Z'}, 'typeLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'blog post'}, 'itemLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Preserving community history with Wikibase'}, 'langLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'English'}}
# {'item': {'type': 'uri', 'value': 'https://dhwiki.wikibase.cloud/entity/Q526'}, 'date': {'datatype': 'http://www.w3.org/2001/XMLSchema#dateTime', 'type': 'literal', 'value': '2024-01-01T00:00:00Z'}, 'typeLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'journal article'}, 'itemLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Formalizing and Validating Wikidata’s Property Constraints using SHACL and SPARQL'}, 'langLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'English'}}
# {'item': {'type': 'uri', 'value': 'https://dhwiki.wikibase.cloud/entity/Q528'}, 'date': {'datatype': 'http://www.w3.org/2001/XMLSchema#dateTime', 'type': 'literal', 'value': '2024-01-01T00:00:00Z'}, 'typeLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'journal article'}, 'itemLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Encoding Archaeological Data Models as Wikidata Schemas: Utilizing Shape Expressions to Structure Collaborative Linked Open Data for Digital Storytelling Within the International Dura-Europos Archive'}, 'langLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'English'}}
# {'item': {'type': 'uri', 'value': 'https://dhwiki.wikibase.cloud/entity/Q534'}, 'date': {'datatype': 'http://www.w3.org/2001/XMLSchema#dateTime', 'type': 'literal', 'value': '2024-12-23T00:00:00Z'}, 'typeLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'journal article'}, 'itemLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Ontolagoon: verso un’ontologia digitale del lessico della pesca nella laguna veneziana'}, 'langLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Italian'}}
# {'item': {'type': 'uri', 'value': 'https://dhwiki.wikibase.cloud/entity/Q537'}, 'date': {'datatype': 'http://www.w3.org/2001/XMLSchema#dateTime', 'type': 'literal', 'value': '2024-12-20T00:00:00Z'}, 'typeLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'journal article'}, 'itemLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Library Data in Wikimedia Projects: Case Study from the Czech Republic'}, 'langLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'English'}}
# {'item': {'type': 'uri', 'value': 'https://dhwiki.wikibase.cloud/entity/Q538'}, 'date': {'datatype': 'http://www.w3.org/2001/XMLSchema#dateTime', 'type': 'literal', 'value': '2024-10-28T00:00:00Z'}, 'typeLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'thesis'}, 'itemLabel': {'xml:lang': 'en', 'type': 'literal', 'value': "Altinum. Un progetto Wikidata per l'epigrafia digitale"}, 'langLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Italian'}}
# {'item': {'type': 'uri', 'value': 'https://dhwiki.wikibase.cloud/entity/Q547'}, 'date': {'datatype': 'http://www.w3.org/2001/XMLSchema#dateTime', 'type': 'literal', 'value': '2024-12-03T00:00:00Z'}, 'typeLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'presentation'}, 'itemLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'DataLib: a relational database about Libanius’ Epistles'}, 'langLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'English'}}
# {'item': {'type': 'uri', 'value': 'https://dhwiki.wikibase.cloud/entity/Q549'}, 'date': {'datatype': 'http://www.w3.org/2001/XMLSchema#dateTime', 'type': 'literal', 'value': '2024-01-01T00:00:00Z'}, 'typeLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'journal article'}, 'itemLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Ontology design facilitating Wikibase integration — and a worked example for historical data'}, 'langLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'English'}}
# {'item': {'type': 'uri', 'value': 'https://dhwiki.wikibase.cloud/entity/Q552'}, 'date': {'datatype': 'http://www.w3.org/2001/XMLSchema#dateTime', 'type': 'literal', 'value': '2024-06-13T00:00:00Z'}, 'typeLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'journal article'}, 'itemLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Using Wikidata lexemes and items to generate text from abstract representations'}, 'langLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'English'}}
# {'item': {'type': 'uri', 'value': 'https://dhwiki.wikibase.cloud/entity/Q558'}, 'date': {'datatype': 'http://www.w3.org/2001/XMLSchema#dateTime', 'type': 'literal', 'value': '2024-08-06T00:00:00Z'}, 'typeLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'journal article'}, 'itemLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Conceptual Modeling of European Silk Heritage with the SILKNOW Data Model and Extension'}, 'langLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'English'}}
# {'item': {'type': 'uri', 'value': 'https://dhwiki.wikibase.cloud/entity/Q566'}, 'date': {'datatype': 'http://www.w3.org/2001/XMLSchema#dateTime', 'type': 'literal', 'value': '2024-04-02T00:00:00Z'}, 'typeLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'journal article'}, 'itemLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Entity Management Using RDA and Wikibase: A Case Study at the National Library of Greece'}, 'langLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'English'}}
# {'item': {'type': 'uri', 'value': 'https://dhwiki.wikibase.cloud/entity/Q479'}, 'date': {'datatype': 'http://www.w3.org/2001/XMLSchema#dateTime', 'type': 'literal', 'value': '2024-04-09T00:00:00Z'}, 'typeLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'presentation'}, 'itemLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Wikidata per la ricerca (nelle università)'}, 'langLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Italian'}}
# {'item': {'type': 'uri', 'value': 'https://dhwiki.wikibase.cloud/entity/Q482'}, 'date': {'datatype': 'http://www.w3.org/2001/XMLSchema#dateTime', 'type': 'literal', 'value': '2024-01-01T00:00:00Z'}, 'typeLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'book section'}, 'itemLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'A Systematic Review of Wikidata in GLAM Institutions: a Labs Approach'}, 'langLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'English'}}
# {'item': {'type': 'uri', 'value': 'https://dhwiki.wikibase.cloud/entity/Q483'}, 'date': {'datatype': 'http://www.w3.org/2001/XMLSchema#dateTime', 'type': 'literal', 'value': '2024-10-09T00:00:00Z'}, 'typeLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'presentation'}, 'itemLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Ontologia e vocabolari controllati'}, 'langLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Italian'}}
# {'item': {'type': 'uri', 'value': 'https://dhwiki.wikibase.cloud/entity/Q221'}, 'date': {'datatype': 'http://www.w3.org/2001/XMLSchema#dateTime', 'type': 'literal', 'value': '2024-05-19T00:00:00Z'}, 'typeLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'presentation'}, 'itemLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Corpus annotation and dictionary linking using Wikibase'}, 'langLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'English'}}
# {'item': {'type': 'uri', 'value': 'https://dhwiki.wikibase.cloud/entity/Q227'}, 'date': {'datatype': 'http://www.w3.org/2001/XMLSchema#dateTime', 'type': 'literal', 'value': '2024-06-19T00:00:00Z'}, 'typeLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'presentation'}, 'itemLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'ZotWb: migrating bibliographical data from a Zotero group library to a custom Wikibase instance'}, 'langLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'English'}}
# {'item': {'type': 'uri', 'value': 'https://dhwiki.wikibase.cloud/entity/Q212'}, 'date': {'datatype': 'http://www.w3.org/2001/XMLSchema#dateTime', 'type': 'literal', 'value': '2024-05-31T00:00:00Z'}, 'typeLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'presentation'}, 'itemLabel': {'xml:lang': 'en', 'type': 'literal', 'value': "Workflows para 'five-star Open Data' usando infraestructuras libres"}, 'langLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Spanish'}}
# {'item': {'type': 'uri', 'value': 'https://dhwiki.wikibase.cloud/entity/Q229'}, 'date': {'datatype': 'http://www.w3.org/2001/XMLSchema#dateTime', 'type': 'literal', 'value': '2024-06-28T00:00:00Z'}, 'typeLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'blog post'}, 'itemLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Modeling the Enlightenment novel: an interview with the MiMoText team'}, 'langLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'English'}}
# {'item': {'type': 'uri', 'value': 'https://dhwiki.wikibase.cloud/entity/Q230'}, 'date': {'datatype': 'http://www.w3.org/2001/XMLSchema#dateTime', 'type': 'literal', 'value': '2024-01-01T00:00:00Z'}, 'typeLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'book section'}, 'itemLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Testu historikoak wiki-plataformetan, Datu Lotu gisa'}, 'langLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Basque'}}
# {'item': {'type': 'uri', 'value': 'https://dhwiki.wikibase.cloud/entity/Q250'}, 'date': {'datatype': 'http://www.w3.org/2001/XMLSchema#dateTime', 'type': 'literal', 'value': '2024-01-01T00:00:00Z'}, 'typeLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'book'}, 'itemLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Common European data space for cultural heritage: annual report 2022/2023.'}, 'langLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'English'}}
# {'item': {'type': 'uri', 'value': 'https://dhwiki.wikibase.cloud/entity/Q250'}, 'date': {'datatype': 'http://www.w3.org/2001/XMLSchema#dateTime', 'type': 'literal', 'value': '2024-01-01T00:00:00Z'}, 'typeLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'report'}, 'itemLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Common European data space for cultural heritage: annual report 2022/2023.'}, 'langLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'English'}}
# {'item': {'type': 'uri', 'value': 'https://dhwiki.wikibase.cloud/entity/Q259'}, 'date': {'datatype': 'http://www.w3.org/2001/XMLSchema#dateTime', 'type': 'literal', 'value': '2024-01-01T00:00:00Z'}, 'typeLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'book'}, 'itemLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Heritage Interpretation: a look from Europe. Handbook of Best Practices'}, 'langLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'English'}}
# {'item': {'type': 'uri', 'value': 'https://dhwiki.wikibase.cloud/entity/Q444'}, 'date': {'datatype': 'http://www.w3.org/2001/XMLSchema#dateTime', 'type': 'literal', 'value': '2024-02-13T00:00:00Z'}, 'typeLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'blog post'}, 'itemLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Learning with Wikibase Partners Outside the EU and North America'}, 'langLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'English'}}
# {'item': {'type': 'uri', 'value': 'https://dhwiki.wikibase.cloud/entity/Q446'}, 'date': {'datatype': 'http://www.w3.org/2001/XMLSchema#dateTime', 'type': 'literal', 'value': '2024-10-08T00:00:00Z'}, 'typeLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'book section'}, 'itemLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Linking Historical Corpus Data and Annotations using Wikibase'}, 'langLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'English'}}
# {'item': {'type': 'uri', 'value': 'https://dhwiki.wikibase.cloud/entity/Q447'}, 'date': {'datatype': 'http://www.w3.org/2001/XMLSchema#dateTime', 'type': 'literal', 'value': '2024-10-08T00:00:00Z'}, 'typeLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'book section'}, 'itemLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Teaching Terminology through Wikibase and Wikidata'}, 'langLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'English'}}
# {'item': {'type': 'uri', 'value': 'https://dhwiki.wikibase.cloud/entity/Q466'}, 'date': {'datatype': 'http://www.w3.org/2001/XMLSchema#dateTime', 'type': 'literal', 'value': '2024-11-15T00:00:00Z'}, 'typeLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'presentation'}, 'itemLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Improving catalogues and cataloguing through Wikidata'}, 'langLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'English'}}
# {'item': {'type': 'uri', 'value': 'https://dhwiki.wikibase.cloud/entity/Q467'}, 'date': {'datatype': 'http://www.w3.org/2001/XMLSchema#dateTime', 'type': 'literal', 'value': '2024-01-01T00:00:00Z'}, 'typeLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'book section'}, 'itemLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Storia della collaborazione tra Wikidata e le biblioteche della Rete URBE nel controllo di autorità'}, 'langLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Italian'}}
# {'item': {'type': 'uri', 'value': 'https://dhwiki.wikibase.cloud/entity/Q468'}, 'date': {'datatype': 'http://www.w3.org/2001/XMLSchema#dateTime', 'type': 'literal', 'value': '2024-01-15T00:00:00Z'}, 'typeLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'journal article'}, 'itemLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Riconciliare le voci di autorità in SBN con Wikidata. Progressi e prospettive dopo un decennio di lavoro (2013-2023)'}, 'langLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Italian'}}
# {'item': {'type': 'uri', 'value': 'https://dhwiki.wikibase.cloud/entity/Q470'}, 'date': {'datatype': 'http://www.w3.org/2001/XMLSchema#dateTime', 'type': 'literal', 'value': '2024-10-30T00:00:00Z'}, 'typeLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'presentation'}, 'itemLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'AuthorityBox e Alphabetica'}, 'langLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Italian'}}
# {'item': {'type': 'uri', 'value': 'https://dhwiki.wikibase.cloud/entity/Q471'}, 'date': {'datatype': 'http://www.w3.org/2001/XMLSchema#dateTime', 'type': 'literal', 'value': '2024-11-08T00:00:00Z'}, 'typeLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'presentation'}, 'itemLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Authority Control reso facile da Wikidata'}, 'langLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Italian'}}
# {'item': {'type': 'uri', 'value': 'https://dhwiki.wikibase.cloud/entity/Q472'}, 'date': {'datatype': 'http://www.w3.org/2001/XMLSchema#dateTime', 'type': 'literal', 'value': '2024-11-08T00:00:00Z'}, 'typeLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'presentation'}, 'itemLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Laboratorio: Wikidata per le biblioteche accademiche'}, 'langLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Italian'}}
# {'item': {'type': 'uri', 'value': 'https://dhwiki.wikibase.cloud/entity/Q473'}, 'date': {'datatype': 'http://www.w3.org/2001/XMLSchema#dateTime', 'type': 'literal', 'value': '2024-04-17T00:00:00Z'}, 'typeLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'presentation'}, 'itemLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Wikidata e Wikibase per strutturare i dati'}, 'langLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Italian'}}
# {'item': {'type': 'uri', 'value': 'https://dhwiki.wikibase.cloud/entity/Q474'}, 'date': {'datatype': 'http://www.w3.org/2001/XMLSchema#dateTime', 'type': 'literal', 'value': '2024-01-01T00:00:00Z'}, 'typeLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'conference paper'}, 'itemLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Conflations and Duplications in Wikidata Items: Causes, Detection, Solutions, and Issues'}, 'langLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'English'}}
# {'item': {'type': 'uri', 'value': 'https://dhwiki.wikibase.cloud/entity/Q484'}, 'date': {'datatype': 'http://www.w3.org/2001/XMLSchema#dateTime', 'type': 'literal', 'value': '2023-10-14T00:00:00Z'}, 'typeLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'journal article'}, 'itemLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'VIAFbot and the integration of library data on Wikipedia'}, 'langLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'English'}}
# {'item': {'type': 'uri', 'value': 'https://dhwiki.wikibase.cloud/entity/Q530'}, 'date': {'datatype': 'http://www.w3.org/2001/XMLSchema#dateTime', 'type': 'literal', 'value': '2023-01-01T00:00:00Z'}, 'typeLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'conference paper'}, 'itemLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Alignment of Wikidata lexemes and Det Centrale Ordregister'}, 'langLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'English'}}
# {'item': {'type': 'uri', 'value': 'https://dhwiki.wikibase.cloud/entity/Q532'}, 'date': {'datatype': 'http://www.w3.org/2001/XMLSchema#dateTime', 'type': 'literal', 'value': '2023-08-01T00:00:00Z'}, 'typeLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'preprint'}, 'itemLabel': {'xml:lang': 'en', 'type': 'literal', 'value': "CoSMo: A constructor specification language for Abstract Wikipedia's content selection process"}, 'langLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'English'}}
# {'item': {'type': 'uri', 'value': 'https://dhwiki.wikibase.cloud/entity/Q541'}, 'date': {'datatype': 'http://www.w3.org/2001/XMLSchema#dateTime', 'type': 'literal', 'value': '2023-01-01T00:00:00Z'}, 'typeLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'book section'}, 'itemLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Sketching an ontology for Leichte Sprache and using it to represent information in Wikidata'}, 'langLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'English'}}
# {'item': {'type': 'uri', 'value': 'https://dhwiki.wikibase.cloud/entity/Q543'}, 'date': {'datatype': 'http://www.w3.org/2001/XMLSchema#dateTime', 'type': 'literal', 'value': '2023-04-14T00:00:00Z'}, 'typeLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'journal article'}, 'itemLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Queer Identities, Normative Databases: Challenges to Capturing Queerness On Wikidata'}, 'langLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'English'}}
# {'item': {'type': 'uri', 'value': 'https://dhwiki.wikibase.cloud/entity/Q559'}, 'date': {'datatype': 'http://www.w3.org/2001/XMLSchema#dateTime', 'type': 'literal', 'value': '2023-01-01T00:00:00Z'}, 'typeLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'journal article'}, 'itemLabel': {'xml:lang': 'en', 'type': 'literal', 'value': '"Only Connect": Linking Up Data in the Schoenberg Database of Manuscripts'}, 'langLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'English'}}
# {'item': {'type': 'uri', 'value': 'https://dhwiki.wikibase.cloud/entity/Q560'}, 'date': {'datatype': 'http://www.w3.org/2001/XMLSchema#dateTime', 'type': 'literal', 'value': '2023-09-30T00:00:00Z'}, 'typeLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'journal article'}, 'itemLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Wikibase Model for Premodern Manuscript Metadata Harmonization, Linked Data Integration, and Discovery'}, 'langLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'English'}}
# {'item': {'type': 'uri', 'value': 'https://dhwiki.wikibase.cloud/entity/Q565'}, 'date': {'datatype': 'http://www.w3.org/2001/XMLSchema#dateTime', 'type': 'literal', 'value': '2023-04-03T00:00:00Z'}, 'typeLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'journal article'}, 'itemLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Leveraging the Power of Crowdsourcing and Linked Open Data: Transformation of the Schoenberg Database of Manuscripts and the SDBM Name and Place Authorities'}, 'langLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'English'}}
# {'item': {'type': 'uri', 'value': 'https://dhwiki.wikibase.cloud/entity/Q571'}, 'date': {'datatype': 'http://www.w3.org/2001/XMLSchema#dateTime', 'type': 'literal', 'value': '2023-01-01T00:00:00Z'}, 'typeLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'book section'}, 'itemLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Multilingual Text Generation for Abstract Wikipedia in Grammatical Framework: Prospects and Challenges'}, 'langLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'English'}}
# {'item': {'type': 'uri', 'value': 'https://dhwiki.wikibase.cloud/entity/Q576'}, 'date': {'datatype': 'http://www.w3.org/2001/XMLSchema#dateTime', 'type': 'literal', 'value': '2023-12-05T00:00:00Z'}, 'typeLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'conference paper'}, 'itemLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'O2WB: A tool enabling ontology reuse in Wikibase'}, 'langLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'English'}}
# {'item': {'type': 'uri', 'value': 'https://dhwiki.wikibase.cloud/entity/Q578'}, 'date': {'datatype': 'http://www.w3.org/2001/XMLSchema#dateTime', 'type': 'literal', 'value': '2023-04-20T00:00:00Z'}, 'typeLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'conference paper'}, 'itemLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Creating Linked Data with Wikibase.Cloud: Evans-Tibbs Archive Wikibase Project'}, 'langLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'English'}}
# {'item': {'type': 'uri', 'value': 'https://dhwiki.wikibase.cloud/entity/Q481'}, 'date': {'datatype': 'http://www.w3.org/2001/XMLSchema#dateTime', 'type': 'literal', 'value': '2023-04-30T00:00:00Z'}, 'typeLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'conference paper'}, 'itemLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Wikidata: The Making Of'}, 'langLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'English'}}
# {'item': {'type': 'uri', 'value': 'https://dhwiki.wikibase.cloud/entity/Q222'}, 'date': {'datatype': 'http://www.w3.org/2001/XMLSchema#dateTime', 'type': 'literal', 'value': '2023-11-15T00:00:00Z'}, 'typeLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'journal article'}, 'itemLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'The Lexmeta Model for Lexical Resources: Theoretical and Implementation Issues'}, 'langLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'English'}, 'wikidata': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124134559'}}
# {'item': {'type': 'uri', 'value': 'https://dhwiki.wikibase.cloud/entity/Q226'}, 'date': {'datatype': 'http://www.w3.org/2001/XMLSchema#dateTime', 'type': 'literal', 'value': '2023-01-01T00:00:00Z'}, 'typeLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'journal article'}, 'itemLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'QICHWABASE: A Quechua Language and Knowledge Base for Quechua Communities'}, 'langLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'English'}, 'wikidata': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q123130404'}}
# {'item': {'type': 'uri', 'value': 'https://dhwiki.wikibase.cloud/entity/Q268'}, 'date': {'datatype': 'http://www.w3.org/2001/XMLSchema#dateTime', 'type': 'literal', 'value': '2023-01-01T00:00:00Z'}, 'typeLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'journal article'}, 'itemLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'DFG Practical Guidelines on Digitisation. Updated version 2022'}, 'langLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'English'}, 'wikidata': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q127524766'}}
# {'item': {'type': 'uri', 'value': 'https://dhwiki.wikibase.cloud/entity/Q270'}, 'date': {'datatype': 'http://www.w3.org/2001/XMLSchema#dateTime', 'type': 'literal', 'value': '2023-01-01T00:00:00Z'}, 'typeLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'journal article'}, 'itemLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'A checklist to publish collections as data in GLAM institutions'}, 'langLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'English'}, 'wikidata': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q123759787'}}
# {'item': {'type': 'uri', 'value': 'https://dhwiki.wikibase.cloud/entity/Q278'}, 'date': {'datatype': 'http://www.w3.org/2001/XMLSchema#dateTime', 'type': 'literal', 'value': '2023-09-07T00:00:00Z'}, 'typeLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'journal article'}, 'itemLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'The case for a common, reusable Knowledge Graph Infrastructure for NFDI'}, 'langLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'English'}, 'wikidata': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q127527723'}}
# {'item': {'type': 'uri', 'value': 'https://dhwiki.wikibase.cloud/entity/Q281'}, 'date': {'datatype': 'http://www.w3.org/2001/XMLSchema#dateTime', 'type': 'literal', 'value': '2023-04-05T00:00:00Z'}, 'typeLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'journal article'}, 'itemLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'A strategy for archives metadata representation on CIDOC-CRM and knowledge discovery'}, 'langLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'English'}, 'wikidata': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q122576418'}}
# {'item': {'type': 'uri', 'value': 'https://dhwiki.wikibase.cloud/entity/Q207'}, 'date': {'datatype': 'http://www.w3.org/2001/XMLSchema#dateTime', 'type': 'literal', 'value': '2023-01-01T00:00:00Z'}, 'typeLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'web page'}, 'itemLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'A workflow to publish Collections as Data: the case of Cultural Heritage data spaces'}, 'langLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'English'}}
# {'item': {'type': 'uri', 'value': 'https://dhwiki.wikibase.cloud/entity/Q220'}, 'date': {'datatype': 'http://www.w3.org/2001/XMLSchema#dateTime', 'type': 'literal', 'value': '2023-07-13T00:00:00Z'}, 'typeLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'conference paper'}, 'itemLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Bibliodata LODification using free software'}, 'langLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'English'}}
# {'item': {'type': 'uri', 'value': 'https://dhwiki.wikibase.cloud/entity/Q224'}, 'date': {'datatype': 'http://www.w3.org/2001/XMLSchema#dateTime', 'type': 'literal', 'value': '2023-01-01T00:00:00Z'}, 'typeLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'journal article'}, 'itemLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'When OntoLex Meets Wikibase: Remodeling Use Cases'}, 'langLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'English'}}
# {'item': {'type': 'uri', 'value': 'https://dhwiki.wikibase.cloud/entity/Q215'}, 'date': {'datatype': 'http://www.w3.org/2001/XMLSchema#dateTime', 'type': 'literal', 'value': '2023-12-16T00:00:00Z'}, 'typeLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'conference paper'}, 'itemLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'A kis gömböc meséje – az ITIdata irodalomtudományos adatbázis fejlesztése 2022–2023-ban'}, 'langLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Hungarian'}}
# {'item': {'type': 'uri', 'value': 'https://dhwiki.wikibase.cloud/entity/Q232'}, 'date': {'datatype': 'http://www.w3.org/2001/XMLSchema#dateTime', 'type': 'literal', 'value': '2023-05-19T00:00:00Z'}, 'typeLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'presentation'}, 'itemLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Euskarazko ekoizpen zientifikoa: Ikergazte Ingumaren ispiluan'}, 'langLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Basque'}}
# {'item': {'type': 'uri', 'value': 'https://dhwiki.wikibase.cloud/entity/Q234'}, 'date': {'datatype': 'http://www.w3.org/2001/XMLSchema#dateTime', 'type': 'literal', 'value': '2023-11-23T00:00:00Z'}, 'typeLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'presentation'}, 'itemLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Testu historikoak wiki-plataformetan, Datu Lotu gisa'}, 'langLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Basque'}}
# {'item': {'type': 'uri', 'value': 'https://dhwiki.wikibase.cloud/entity/Q242'}, 'date': {'datatype': 'http://www.w3.org/2001/XMLSchema#dateTime', 'type': 'literal', 'value': '2023-05-25T00:00:00Z'}, 'typeLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'presentation'}, 'itemLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'LiLa and Wikidata: Building Bridges'}, 'langLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'English'}}
# {'item': {'type': 'uri', 'value': 'https://dhwiki.wikibase.cloud/entity/Q247'}, 'date': {'datatype': 'http://www.w3.org/2001/XMLSchema#dateTime', 'type': 'literal', 'value': '2023-01-01T00:00:00Z'}, 'typeLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'book section'}, 'itemLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Inguma eta Wikidata uztartuz, euskarazko zientziaren ezagutza-graforantz'}, 'langLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Basque'}}
# {'item': {'type': 'uri', 'value': 'https://dhwiki.wikibase.cloud/entity/Q252'}, 'date': {'datatype': 'http://www.w3.org/2001/XMLSchema#dateTime', 'type': 'literal', 'value': '2023-07-07T00:00:00Z'}, 'typeLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'presentation'}, 'itemLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Datu Lotuak, Ezagutza Grafoak, Wikidata, Wikibase'}, 'langLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Basque'}}
# {'item': {'type': 'uri', 'value': 'https://dhwiki.wikibase.cloud/entity/Q262'}, 'date': {'datatype': 'http://www.w3.org/2001/XMLSchema#dateTime', 'type': 'literal', 'value': '2023-03-20T00:00:00Z'}, 'typeLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'journal article'}, 'itemLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'The Current State and Challenges in Democratizing Small Museums’ Collections Online'}, 'langLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'English'}}
# {'item': {'type': 'uri', 'value': 'https://dhwiki.wikibase.cloud/entity/Q266'}, 'date': {'datatype': 'http://www.w3.org/2001/XMLSchema#dateTime', 'type': 'literal', 'value': '2023-01-01T00:00:00Z'}, 'typeLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'book section'}, 'itemLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'The Semantic Mapping of RiC-CM to CIDOC-CRM'}, 'langLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'English'}}
# {'item': {'type': 'uri', 'value': 'https://dhwiki.wikibase.cloud/entity/Q269'}, 'date': {'datatype': 'http://www.w3.org/2001/XMLSchema#dateTime', 'type': 'literal', 'value': '2023-05-25T00:00:00Z'}, 'typeLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'report'}, 'itemLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Mid-term results – Matrix and methodology assessment. CHARTER Consortium.'}, 'langLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'English'}}
# {'item': {'type': 'uri', 'value': 'https://dhwiki.wikibase.cloud/entity/Q285'}, 'date': {'datatype': 'http://www.w3.org/2001/XMLSchema#dateTime', 'type': 'literal', 'value': '2023-08-25T00:00:00Z'}, 'typeLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'report'}, 'itemLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Decentralised Aggregation in the Data Space for Cultural Heritage: Opportunities, Challenges and Governance Implications'}, 'langLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'English'}}
# {'item': {'type': 'uri', 'value': 'https://dhwiki.wikibase.cloud/entity/Q475'}, 'date': {'datatype': 'http://www.w3.org/2001/XMLSchema#dateTime', 'type': 'literal', 'value': '2023-01-01T00:00:00Z'}, 'typeLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'book section'}, 'itemLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'IRIS e Wikidata: un progetto per una migliore valorizzazione e fruizione degli archivi della ricerca scientifica italiana'}, 'langLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Italian'}}
# {'item': {'type': 'uri', 'value': 'https://dhwiki.wikibase.cloud/entity/Q531'}, 'date': {'datatype': 'http://www.w3.org/2001/XMLSchema#dateTime', 'type': 'literal', 'value': '2022-06-01T00:00:00Z'}, 'typeLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'conference paper'}, 'itemLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Connecting a French Dictionary from the Beginning of the 20th Century to Wikidata'}, 'langLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'English'}}
# {'item': {'type': 'uri', 'value': 'https://dhwiki.wikibase.cloud/entity/Q540'}, 'date': {'datatype': 'http://www.w3.org/2001/XMLSchema#dateTime', 'type': 'literal', 'value': '2022-07-07T00:00:00Z'}, 'typeLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'journal article'}, 'itemLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Wikidata and the bibliography of life'}, 'langLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'English'}}
# {'item': {'type': 'uri', 'value': 'https://dhwiki.wikibase.cloud/entity/Q545'}, 'date': {'datatype': 'http://www.w3.org/2001/XMLSchema#dateTime', 'type': 'literal', 'value': '2022-07-27T00:00:00Z'}, 'typeLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'journal article'}, 'itemLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Leveraging Wikidata to Build Scholarly Profiles as Service'}, 'langLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'English'}}
# {'item': {'type': 'uri', 'value': 'https://dhwiki.wikibase.cloud/entity/Q550'}, 'date': {'datatype': 'http://www.w3.org/2001/XMLSchema#dateTime', 'type': 'literal', 'value': '2022-01-01T00:00:00Z'}, 'typeLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'journal article'}, 'itemLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'International Journal of Humanities and Arts Computing. Special Issue: Linked Open Data in the Arts and the Humanities'}, 'langLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'English'}}
# {'item': {'type': 'uri', 'value': 'https://dhwiki.wikibase.cloud/entity/Q556'}, 'date': {'datatype': 'http://www.w3.org/2001/XMLSchema#dateTime', 'type': 'literal', 'value': '2022-01-01T00:00:00Z'}, 'typeLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'journal article'}, 'itemLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'A Simple Standard for Sharing Ontological Mappings (SSSOM)'}, 'langLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'English'}}
# {'item': {'type': 'uri', 'value': 'https://dhwiki.wikibase.cloud/entity/Q557'}, 'date': {'datatype': 'http://www.w3.org/2001/XMLSchema#dateTime', 'type': 'literal', 'value': '2022-01-01T00:00:00Z'}, 'typeLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'conference paper'}, 'itemLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Modelling frequency, attestation, and corpus-based information with OntoLex-FrAC'}, 'langLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'English'}}
# {'item': {'type': 'uri', 'value': 'https://dhwiki.wikibase.cloud/entity/Q561'}, 'date': {'datatype': 'http://www.w3.org/2001/XMLSchema#dateTime', 'type': 'literal', 'value': '2022-09-15T00:00:00Z'}, 'typeLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'journal article'}, 'itemLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Wikibase, or The search for the unicorn'}, 'langLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Italian'}}
# {'item': {'type': 'uri', 'value': 'https://dhwiki.wikibase.cloud/entity/Q577'}, 'date': {'datatype': 'http://www.w3.org/2001/XMLSchema#dateTime', 'type': 'literal', 'value': '2022-11-03T00:00:00Z'}, 'typeLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'conference paper'}, 'itemLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Analysing and promoting ontology interoperability in Wikibase'}, 'langLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'English'}}
# {'item': {'type': 'uri', 'value': 'https://dhwiki.wikibase.cloud/entity/Q580'}, 'date': {'datatype': 'http://www.w3.org/2001/XMLSchema#dateTime', 'type': 'literal', 'value': '2022-03-16T00:00:00Z'}, 'typeLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'blog post'}, 'itemLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Examining Wikidata and Wikibase in the context of research data management applications'}, 'langLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'English'}}
# {'item': {'type': 'uri', 'value': 'https://dhwiki.wikibase.cloud/entity/Q211'}, 'date': {'datatype': 'http://www.w3.org/2001/XMLSchema#dateTime', 'type': 'literal', 'value': '2022-01-01T00:00:00Z'}, 'typeLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'journal article'}, 'itemLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Reusing digital collections from GLAM institutions'}, 'langLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'English'}, 'wikidata': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q119959336'}}
# {'item': {'type': 'uri', 'value': 'https://dhwiki.wikibase.cloud/entity/Q277'}, 'date': {'datatype': 'http://www.w3.org/2001/XMLSchema#dateTime', 'type': 'literal', 'value': '2022-01-01T00:00:00Z'}, 'typeLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'conference paper'}, 'itemLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Using Wikibase for\xa0Managing Cultural Heritage Linked Open Data Based on\xa0CIDOC CRM'}, 'langLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'English'}, 'wikidata': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q114839518'}}
# {'item': {'type': 'uri', 'value': 'https://dhwiki.wikibase.cloud/entity/Q280'}, 'date': {'datatype': 'http://www.w3.org/2001/XMLSchema#dateTime', 'type': 'literal', 'value': '2022-09-15T00:00:00Z'}, 'typeLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'journal article'}, 'itemLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'The entities of the IFLA-LRM, RiC-CM and CIDOC-CRM models in the semantic web'}, 'langLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Italian'}, 'wikidata': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q114369732'}}
# ...
# {'item': {'type': 'uri', 'value': 'https://dhwiki.wikibase.cloud/entity/Q570'}, 'date': {'datatype': 'http://www.w3.org/2001/XMLSchema#dateTime', 'type': 'literal', 'value': '2019-01-01T00:00:00Z'}, 'typeLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'thesis'}, 'itemLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Modelling and Importing Dynamic Data into Wikibase'}, 'langLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'English'}}
# {'item': {'type': 'uri', 'value': 'https://dhwiki.wikibase.cloud/entity/Q236'}, 'date': {'datatype': 'http://www.w3.org/2001/XMLSchema#dateTime', 'type': 'literal', 'value': '2019-08-20T00:00:00Z'}, 'typeLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'conference paper'}, 'itemLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'What we talk about when we talk about wikidata quality: a literature survey'}, 'langLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'English'}, 'wikidata': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q66776851'}}
# {'item': {'type': 'uri', 'value': 'https://dhwiki.wikibase.cloud/entity/Q241'}, 'date': {'datatype': 'http://www.w3.org/2001/XMLSchema#dateTime', 'type': 'literal', 'value': '2019-09-02T00:00:00Z'}, 'typeLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'journal article'}, 'itemLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'A systematic literature review on Wikidata'}, 'langLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'English'}, 'wikidata': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q66724305'}}
# {'item': {'type': 'uri', 'value': 'https://dhwiki.wikibase.cloud/entity/Q244'}, 'date': {'datatype': 'http://www.w3.org/2001/XMLSchema#dateTime', 'type': 'literal', 'value': '2019-06-17T00:00:00Z'}, 'typeLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'journal article'}, 'itemLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Wikidata: From “an” Identifier to “the” Identifier'}, 'langLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'English'}, 'wikidata': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q66058088'}}
# {'item': {'type': 'uri', 'value': 'https://dhwiki.wikibase.cloud/entity/Q255'}, 'date': {'datatype': 'http://www.w3.org/2001/XMLSchema#dateTime', 'type': 'literal', 'value': '2019-01-01T00:00:00Z'}, 'typeLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'journal article'}, 'itemLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'The uses of Wikidata for galleries, libraries, archives and museums and its place in the digital humanities'}, 'langLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'English'}, 'wikidata': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q63761695'}}
# {'item': {'type': 'uri', 'value': 'https://dhwiki.wikibase.cloud/entity/Q208'}, 'date': {'datatype': 'http://www.w3.org/2001/XMLSchema#dateTime', 'type': 'literal', 'value': '2019-08-05T00:00:00Z'}, 'typeLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'report'}, 'itemLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Creating library linked data with Wikibase: Lessons learned from Project Passage'}, 'langLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'English'}}
# {'item': {'type': 'uri', 'value': 'https://dhwiki.wikibase.cloud/entity/Q245'}, 'date': {'datatype': 'http://www.w3.org/2001/XMLSchema#dateTime', 'type': 'literal', 'value': '2019-01-01T00:00:00Z'}, 'typeLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'journal article'}, 'itemLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Wikidata from a Research Perspective -- A Systematic Mapping Study of Wikidata'}, 'langLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'English'}}
# {'item': {'type': 'uri', 'value': 'https://dhwiki.wikibase.cloud/entity/Q246'}, 'date': {'datatype': 'http://www.w3.org/2001/XMLSchema#dateTime', 'type': 'literal', 'value': '2019-01-01T00:00:00Z'}, 'typeLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'journal article'}, 'itemLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Wikidata, WikiCite y Scholia como herramientas para un corpus de datos bibliográficos enlazados. Curación y estructuración de la producción científica de los investigadores del IATEXT'}, 'langLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Spanish'}}
# {'item': {'type': 'uri', 'value': 'https://dhwiki.wikibase.cloud/entity/Q257'}, 'date': {'datatype': 'http://www.w3.org/2001/XMLSchema#dateTime', 'type': 'literal', 'value': '2019-01-01T00:00:00Z'}, 'typeLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'journal article'}, 'itemLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Wikidata as a FAIR knowledge graph for the life sciences'}, 'langLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'English'}}
# {'item': {'type': 'uri', 'value': 'https://dhwiki.wikibase.cloud/entity/Q216'}, 'date': {'datatype': 'http://www.w3.org/2001/XMLSchema#dateTime', 'type': 'literal', 'value': '2018-01-01T00:00:00Z'}, 'typeLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'journal article'}, 'itemLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'New ways of creating and sharing bibliographic information : an experiment of using the Wikibase Data Model for UNIMARC data'}, 'langLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'English'}, 'wikidata': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q56648870'}}
# {'item': {'type': 'uri', 'value': 'https://dhwiki.wikibase.cloud/entity/Q253'}, 'date': {'datatype': 'http://www.w3.org/2001/XMLSchema#dateTime', 'type': 'literal', 'value': '2018-12-10T00:00:00Z'}, 'typeLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'journal article'}, 'itemLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Creating Structured Linked Data to Generate Scholarly Profiles: A Pilot Project using Wikidata and Scholia'}, 'langLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'English'}, 'wikidata': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q59652985'}}
# {'item': {'type': 'uri', 'value': 'https://dhwiki.wikibase.cloud/entity/Q213'}, 'date': {'datatype': 'http://www.w3.org/2001/XMLSchema#dateTime', 'type': 'literal', 'value': '2018-01-01T00:00:00Z'}, 'typeLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'conference paper'}, 'itemLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Towards a Linked Lexical Data Cloud based on OntoLex-Lemon'}, 'langLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'English'}}
# {'item': {'type': 'uri', 'value': 'https://dhwiki.wikibase.cloud/entity/Q237'}, 'date': {'datatype': 'http://www.w3.org/2001/XMLSchema#dateTime', 'type': 'literal', 'value': '2018-01-01T00:00:00Z'}, 'typeLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'book section'}, 'itemLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Getting the Most Out of Wikidata: Semantic Technology Usage in Wikipedia’s Knowledge Graph'}, 'langLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'English'}}
# {'item': {'type': 'uri', 'value': 'https://dhwiki.wikibase.cloud/entity/Q282'}, 'date': {'datatype': 'http://www.w3.org/2001/XMLSchema#dateTime', 'type': 'literal', 'value': '2018-01-01T00:00:00Z'}, 'typeLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'journal article'}, 'itemLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Wikidata for digital preservation'}, 'langLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'English'}}
# {'item': {'type': 'uri', 'value': 'https://dhwiki.wikibase.cloud/entity/Q527'}, 'date': {'datatype': 'http://www.w3.org/2001/XMLSchema#dateTime', 'type': 'literal', 'value': '2017-10-01T00:00:00Z'}, 'typeLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'conference paper'}, 'itemLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Using WikiData as a multi-lingual multi-dialectal dictionary for Arabic dialects'}, 'langLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'English'}}
# {'item': {'type': 'uri', 'value': 'https://dhwiki.wikibase.cloud/entity/Q228'}, 'date': {'datatype': 'http://www.w3.org/2001/XMLSchema#dateTime', 'type': 'literal', 'value': '2017-01-01T00:00:00Z'}, 'typeLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'conference paper'}, 'itemLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'The OntoLex-Lemon Model: Development and Applications'}, 'langLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'English'}}
# {'item': {'type': 'uri', 'value': 'https://dhwiki.wikibase.cloud/entity/Q251'}, 'date': {'datatype': 'http://www.w3.org/2001/XMLSchema#dateTime', 'type': 'literal', 'value': '2017-01-01T00:00:00Z'}, 'typeLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'book section'}, 'itemLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Scholia, Scientometrics and Wikidata'}, 'langLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'English'}}
# {'item': {'type': 'uri', 'value': 'https://dhwiki.wikibase.cloud/entity/Q272'}, 'date': {'datatype': 'http://www.w3.org/2001/XMLSchema#dateTime', 'type': 'literal', 'value': '2017-01-01T00:00:00Z'}, 'typeLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'book'}, 'itemLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Archives in the digital age: standards, policies and tools'}, 'langLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'English'}}
# {'item': {'type': 'uri', 'value': 'https://dhwiki.wikibase.cloud/entity/Q275'}, 'date': {'datatype': 'http://www.w3.org/2001/XMLSchema#dateTime', 'type': 'literal', 'value': '2017-01-01T00:00:00Z'}, 'typeLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'book'}, 'itemLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Guía del archivo fotográfico'}, 'langLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Spanish'}}
# {'item': {'type': 'uri', 'value': 'https://dhwiki.wikibase.cloud/entity/Q542'}, 'date': {'datatype': 'http://www.w3.org/2001/XMLSchema#dateTime', 'type': 'literal', 'value': '2016-01-01T00:00:00Z'}, 'typeLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'book section'}, 'itemLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Lexical Knowledge Bases'}, 'langLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'English'}}
# {'item': {'type': 'uri', 'value': 'https://dhwiki.wikibase.cloud/entity/Q264'}, 'date': {'datatype': 'http://www.w3.org/2001/XMLSchema#dateTime', 'type': 'literal', 'value': '2016-01-01T00:00:00Z'}, 'typeLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'book section'}, 'itemLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Mapping the Hierarchy of EAD to VRA Core 4.0 Through CIDOC CRM'}, 'langLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'English'}}
# {'item': {'type': 'uri', 'value': 'https://dhwiki.wikibase.cloud/entity/Q568'}, 'date': {'datatype': 'http://www.w3.org/2001/XMLSchema#dateTime', 'type': 'literal', 'value': '2015-01-01T00:00:00Z'}, 'typeLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'book section'}, 'itemLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'LIME: The Metadata Module for OntoLex'}, 'langLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'English'}}
# {'item': {'type': 'uri', 'value': 'https://dhwiki.wikibase.cloud/entity/Q274'}, 'date': {'datatype': 'http://www.w3.org/2001/XMLSchema#dateTime', 'type': 'literal', 'value': '2015-01-01T00:00:00Z'}, 'typeLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'book'}, 'itemLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Patrimonio fotográfico: de la visibilidad a la gestión'}, 'langLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Spanish'}}
# {'item': {'type': 'uri', 'value': 'https://dhwiki.wikibase.cloud/entity/Q258'}, 'date': {'datatype': 'http://www.w3.org/2001/XMLSchema#dateTime', 'type': 'literal', 'value': '2014-01-01T00:00:00Z'}, 'typeLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'journal article'}, 'itemLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Wikidata: a free collaborative knowledgebase'}, 'langLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'English'}, 'wikidata': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q18507561'}}
# {'item': {'type': 'uri', 'value': 'https://dhwiki.wikibase.cloud/entity/Q243'}, 'date': {'datatype': 'http://www.w3.org/2001/XMLSchema#dateTime', 'type': 'literal', 'value': '2014-01-01T00:00:00Z'}, 'typeLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'book section'}, 'itemLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Introducing Wikidata to the Linked Data Web'}, 'langLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'English'}}
# {'item': {'type': 'uri', 'value': 'https://dhwiki.wikibase.cloud/entity/Q223'}, 'date': {'datatype': 'http://www.w3.org/2001/XMLSchema#dateTime', 'type': 'literal', 'value': '2013-01-01T00:00:00Z'}, 'typeLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'conference paper'}, 'itemLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Integrating NLP Using Linked Data'}, 'langLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'English'}, 'wikidata': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q57239566'}}
# {'item': {'type': 'uri', 'value': 'https://dhwiki.wikibase.cloud/entity/Q248'}, 'date': {'datatype': 'http://www.w3.org/2001/XMLSchema#dateTime', 'type': 'literal', 'value': '2012-04-16T00:00:00Z'}, 'typeLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'conference paper'}, 'itemLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Wikidata: a new platform for collaborative data collection'}, 'langLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'English'}, 'wikidata': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q27042516'}}
# {'item': {'type': 'uri', 'value': 'https://dhwiki.wikibase.cloud/entity/Q283'}, 'date': {'datatype': 'http://www.w3.org/2001/XMLSchema#dateTime', 'type': 'literal', 'value': '2012-01-01T00:00:00Z'}, 'typeLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'book section'}, 'itemLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Automatic Generation of Crosswalks through CIDOC CRM'}, 'langLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'English'}}
# {'item': {'type': 'uri', 'value': 'https://dhwiki.wikibase.cloud/entity/Q254'}, 'date': {'datatype': 'http://www.w3.org/2001/XMLSchema#dateTime', 'type': 'literal', 'value': '2011-01-01T00:00:00Z'}, 'typeLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'journal article'}, 'itemLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'The Semantic Mapping of Archival Metadata to the CIDOC CRM Ontology'}, 'langLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'English'}, 'wikidata': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q58535668'}}
# {'item': {'type': 'uri', 'value': 'https://dhwiki.wikibase.cloud/entity/Q271'}, 'date': {'datatype': 'http://www.w3.org/2001/XMLSchema#dateTime', 'type': 'literal', 'value': '2008-01-01T00:00:00Z'}, 'typeLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'conference paper'}, 'itemLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Documenting cultural heritage in small museums'}, 'langLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'English'}}
# {'item': {'type': 'uri', 'value': 'https://dhwiki.wikibase.cloud/entity/Q260'}, 'date': {'datatype': 'http://www.w3.org/2001/XMLSchema#dateTime', 'type': 'literal', 'value': '2006-02-01T00:00:00Z'}, 'typeLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'book'}, 'itemLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Directrices para proyectos de digitalización de colecciones y fondos de dominio público, en particular para aquellos custodiados en bibliotecas y archivos'}, 'langLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Spanish'}}
